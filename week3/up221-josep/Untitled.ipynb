# %%
import pandas as pd

df=pd.read_csv("Journey_to_Work_(2013)_5_Year_Estimates.csv",sep=",")
df
# Out:
#        FID  STATEFP  COUNTYFP  TRACTCE       GEOID     NAME  \
# 0        1        6        37   204920  6037204920  2049.20
# 1        2        6        37   205110  6037205110  2051.10
# 2        3        6        37   205120  6037205120  2051.20
# 3        4        6        37   206010  6037206010  2060.10
# 4        5        6        37   206020  6037206020  2060.20
# ...    ...      ...       ...      ...         ...      ...
# 1163  1164        6        37   651001  6037651001  6510.01
# 1164  1165        6        37   532700  6037532700  5327.00
# 1165  1166        6        37   189600  6037189600  1896.00
# 1166  1167        6        37   189400  6037189400  1894.00
# 1167  1168        6        37   181400  6037181400  1814.00
#
#                   NAMELSAD  MTFCC FUNCSTAT    ALAND  ...  DriveAlone  Carpool  \
# 0     Census Tract 2049.20  G5020        S   909972  ...        70.1     10.4
# 1     Census Tract 2051.10  G5020        S   286960  ...        48.3     17.3
# ...
