# %% [markdown]
# # Week 3 Assignment Census Data
# ## Transportation profile Los Angeles
# ### Commuting times by neighborhoods

# %% [markdown]
# ### The following assignment looks to examine, visualize and represent the data collected from the percentages of workers that commute
# ### longer than 1 hour to their workplace around different neighborhoods in the LA County. This data is a first step to provide results from the places and amount of people that spend significant time getting to their workplace, understanding the complexity and future problems this situation brings to the wellbeing of citizens and their quality of life

# %% [markdown]
# ### Jose Portales

# %%
# First, provide workstation. import pandas to provide library for data exploration
# provide entrance for downloaded data

# %%
import pandas as pd
import geopandas as gpd
neighborhoods=gpd.read_file('incneigh.geojson')

# %%
#First we want to upload the csv files and filter the needed data
# The first csv is from the neighborhoods in LA County. The only file founded for this specifial spatial unit was one from the  Incarceration Impact by neighborhood. It was then renamed and uploaded

# %%
#Check the size of the data
neighborhoods.shape
# Out:
# (244, 20)

# %%
#Check a small sample of the columns and rows
neighborhoods.head()
# Out:
#    OBJECTID  Neighborhood  LAPD_Cost  LAPD_Days_in_Jail  LAPD_Arrests  \
# 0         1         Acton      25282                110            51
# 1         2  Agoura Hills      83892                365           216
# 2         3    Agua Dulce      10573                 46            23
# 3         4      Alhambra     301550               1312           647
# 4         5  Alondra Park      55621                242           112
#
#    LASD_Cost  LASD_Days_in_Jail  LASD_Arrests  F2010_Population  Combo_Cost  \
# 0    1103120               7367           396              6128     1128402
# 1     587038               3288           470             17147      670930
# 2     377880               2513           140             21499      388453
# 3    2444920              16637           751              3535     2746470
# 4     667093               4244           326             83089      722714
#
#    Combo_Cost_PerPop  Combo_Days  Combo_Days_PerPop  Combo_Arrests  \
# 0         184.138708        7477           1.220137            447
# 1          39.128127        3653           0.213040            686
# 2          18.068422        2559           0.119029            163
# 3         776.936351       17949           5.077511           1398
# 4           8.698071        4486           0.053990            438
#
#    Combo_Arrests_PerPop                      spa    sup_dist  SHAPE_Length  \
# 0              0.072944  SPA 1 - Antelope Valley  District 5      0.554615
# 1              0.040007     SPA 2 - San Fernando  District 3      0.255669
# 2              0.007582  SPA 1 - Antelope Valley  District 5      0.439983
# 3              0.395474      SPA 3 - San Gabriel  District 1      0.210733
# 4              0.005271        SPA 8 - South Bay  District 2      0.078123
#
#    SHAPE_Area                                           geometry
# 0    0.010002  MULTIPOLYGON Z (((-118.20262 34.53899 0.00000,...
# 1    0.002063  MULTIPOLYGON Z (((-118.76193 34.16820 0.00000,...
# 2    0.008000  MULTIPOLYGON Z (((-118.25468 34.55830 0.00000,...
# 3    0.001929  MULTIPOLYGON Z (((-118.12175 34.10504 0.00000,...
# 4    0.000288  MULTIPOLYGON Z (((-118.32651 33.89757 0.00000,...

# %%
#Plot the file to undestrand the size of the "geometry" of the geojsn file
neighborhoods.plot(figsize=(12,10))
# Out:
# <Axes: >

# %%
#shorten the data and generate a new dataframe with the deisred information.We only need specific variables and info

columns_to_keep = ['OBJECTID',
                   'spa',
                   'Neighborhood',
                   'sup_dist',
                  'geometry']

# %%
neighborhoods2 = neighborhoods[columns_to_keep]

# %%
#Check the size of the new, trimmed variable
neighborhoods2.shape
# Out:
# (244, 5)

# %%
#Create another variable trimming another information, this time 2 rows that contain information about the unwanted neighborhoods(islands below)

neighborhoods3 = neighborhoods2.drop([11, 207])

# %%
#Check the new variable
neighborhoods3.shape
# Out:
# (242, 5)

# %%
#Plot the new varaible with the unwanted land. Now LA Cojnty has been mapped
neighborhoods3.plot(figsize=(11,12))
# Out:
# <Axes: >

# %%
#Import csv file with the % of commute time above 1 hour by neighborhood in LA County
commute=pd.read_csv('CTLC3.csv', delimiter=';')
commute.head()
# Out:
#          name  year denom_tot_workers  Commute Time Above 1 Hour
# 0   Irwindale  2021            804,94                      15.25
# 1  Pico-Union  2021          18793,13                      16.64
# 2    Glendora  2021           25208,2                      17.26
# 3    Industry  2021           6066,56                      16.16
# 4      Sylmar  2021          36939,14                      11.57

# %%
#For the upcoming merge, we want to change the name of the variable "neighborhood" to allow the merge to work
commute.rename(columns={'name': 'Neighborhood'}, inplace=True)
commute.head()
# Out:
#   Neighborhood  year denom_tot_workers  Commute Time Above 1 Hour
# 0    Irwindale  2021            804,94                      15.25
# 1   Pico-Union  2021          18793,13                      16.64
# 2     Glendora  2021           25208,2                      17.26
# 3     Industry  2021           6066,56                      16.16
# 4       Sylmar  2021          36939,14                      11.57

# %%
#Check bot databases have the same name of columnn
neighborhoods3.head()
# Out:
#    OBJECTID                      spa  Neighborhood    sup_dist  \
# 0         1  SPA 1 - Antelope Valley         Acton  District 5
# 1         2     SPA 2 - San Fernando  Agoura Hills  District 3
# 2         3  SPA 1 - Antelope Valley    Agua Dulce  District 5
# 3         4      SPA 3 - San Gabriel      Alhambra  District 1
# 4         5        SPA 8 - South Bay  Alondra Park  District 2
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-118.20262 34.53899 0.00000,...
# 1  MULTIPOLYGON Z (((-118.76193 34.16820 0.00000,...
# 2  MULTIPOLYGON Z (((-118.25468 34.55830 0.00000,...
# 3  MULTIPOLYGON Z (((-118.12175 34.10504 0.00000,...
# 4  MULTIPOLYGON Z (((-118.32651 33.89757 0.00000,...

# %%
#merge based on common element

merged_df = neighborhoods3.merge(commute,on='Neighborhood')

# %%
#Check the merge was succesfull
merged_df.head()
# Out:
#    OBJECTID                      spa  Neighborhood    sup_dist  \
# 0         1  SPA 1 - Antelope Valley         Acton  District 5
# 1         2     SPA 2 - San Fernando  Agoura Hills  District 3
# 2         3  SPA 1 - Antelope Valley    Agua Dulce  District 5
# 3         4      SPA 3 - San Gabriel      Alhambra  District 1
# 4         5        SPA 8 - South Bay  Alondra Park  District 2
#
#                                             geometry  year denom_tot_workers  \
# 0  MULTIPOLYGON Z (((-118.20262 34.53899 0.00000,...  2021           1448,51
# 1  MULTIPOLYGON Z (((-118.76193 34.16820 0.00000,...  2021            8032,5
# 2  MULTIPOLYGON Z (((-118.25468 34.55830 0.00000,...  2021           2073,33
# 3  MULTIPOLYGON Z (((-118.12175 34.10504 0.00000,...  2021          40794,02
# 4  MULTIPOLYGON Z (((-118.32651 33.89757 0.00000,...  2021           3869,87
#
#    Commute Time Above 1 Hour
# 0                      42.38
# 1                      15.27
# 2                      21.80
# 3                      11.12
# 4                      16.85

# %%
#Check info
merged_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   OBJECTID                   225 non-null    int64
#  1   spa                        225 non-null    object
#  2   Neighborhood               225 non-null    object
#  3   sup_dist                   225 non-null    object
#  4   geometry                   225 non-null    geometry
#  5   year                       225 non-null    int64
#  6   denom_tot_workers          224 non-null    object
#  7   Commute Time Above 1 Hour  224 non-null    float64
# dtypes: float64(1), geometry(1), int64(2), object(4)
# memory usage: 14.2+ KB

# %%
merged_df.shape
# Out:
# (225, 8)

# %%
#Plot the merged database. Blank gaps in the map tells us the mssing neighborhoods in the previous databases
merged_df.plot(figsize=(11,12))
# Out:
# <Axes: >

# %%
City_boundary=gpd.read_file('City_Boundary.geojson')

# %%
import geopandas as gpd

# Assuming merged_df and City_boundary are already defined and loaded as GeoDataFrames

# Clip the merged_df by the City_boundary
clipped_gdf = gpd.clip(merged_df, City_boundary)

# %%
clipped_gdf.plot(figsize=(11,12))
# Out:
# <Axes: >

# %%
clipped_gdf.shape
# Out:
# (121, 8)

# %%
clipped_gdf.head()
# Out:
#      OBJECTID                spa  Neighborhood    sup_dist  \
# 105       117  SPA 8 - South Bay    Long Beach  District 4
# 108       120      SPA 6 - South       Lynwood  District 4
# 176       190       SPA 7 - East    South Gate  District 4
# 40         43       SPA 7 - East      Commerce  District 4
# 209       226  SPA 8 - South Bay  West Compton  District 2
#
#                                               geometry  year  \
# 105  MULTIPOLYGON Z (((-118.22111 33.78299 0.00000,...  2021
# 108  MULTIPOLYGON Z (((-118.23032 33.92900 0.00000,...  2021
# 176  POLYGON Z ((-118.22802 33.94562 0.00000, -118....  2021
# 40   POLYGON Z ((-118.19161 34.01508 0.00000, -118....  2021
# 209  POLYGON Z ((-118.28271 33.88547 0.00000, -118....  2021
#
#     denom_tot_workers  Commute Time Above 1 Hour
# 105         226941,42                      12.77
# 108          27420,91                      13.02
# 176          41502,42                      13.84
# 40             4936,4                      11.17
# 209           2853,16                       7.78

# %%
clipped_gdf.plot(figsize=(11,12),
               column='Commute Time Above 1 Hour',
               legend=True,
               scheme='quantiles')
# Out:
# <Axes: >

# %%
LA_Commute=clipped_gdf

# %%
LA_Commute.head()
# Out:
#      OBJECTID                spa  Neighborhood    sup_dist  \
# 105       117  SPA 8 - South Bay    Long Beach  District 4
# 108       120      SPA 6 - South       Lynwood  District 4
# 176       190       SPA 7 - East    South Gate  District 4
# 40         43       SPA 7 - East      Commerce  District 4
# 209       226  SPA 8 - South Bay  West Compton  District 2
#
#                                               geometry  year  \
# 105  MULTIPOLYGON Z (((-118.22111 33.78299 0.00000,...  2021
# 108  MULTIPOLYGON Z (((-118.23032 33.92900 0.00000,...  2021
# 176  POLYGON Z ((-118.22802 33.94562 0.00000, -118....  2021
# 40   POLYGON Z ((-118.19161 34.01508 0.00000, -118....  2021
# 209  POLYGON Z ((-118.28271 33.88547 0.00000, -118....  2021
#
#     denom_tot_workers  Commute Time Above 1 Hour
# 105         226941,42                      12.77
# 108          27420,91                      13.02
# 176          41502,42                      13.84
# 40             4936,4                      11.17
# 209           2853,16                       7.78

# %%
LA_Commute.shape
# Out:
# (121, 8)

# %%
#A chart that shows the neighborhoods with higher percentages
LA_Commute_top=LA_Commute.sort_values(by='Commute Time Above 1 Hour',ascending = False)

# %%
LA_Commute_top[['Neighborhood','Commute Time Above 1 Hour']].head(10)
# Out:
#                               Neighborhood  Commute Time Above 1 Hour
# 192                        Tujunga Canyons                      32.67
# 194  Unincorporated Santa Susana Mountains                      20.46
# 224                         Woodland Hills                      20.36
# 213                               Westlake                      20.05
# 26                               Calabasas                      19.97
# 189                                Topanga                      18.65
# 64                          Elysian Valley                      18.55
# 168                           Shadow Hills                      18.48
# 199                               Van Nuys                      17.88
# 186                                Tarzana                      17.79

# %%
LA_Commute_top.head(10).plot.bar(x='Neighborhood',
                            y='Commute Time Above 1 Hour')
# Out:
# <Axes: xlabel='Neighborhood'>

# %%
LA_Commute_top.head(5).plot.barh(x='Neighborhood',
                            y='Commute Time Above 1 Hour', 
                            title='Top 10 neighborhoods with the highest percentage of commute to work over 1 hour',
                            color='purple')
# Out:
# <Axes: title={'center': 'Top 10 neighborhoods with the highest percentage of commute to work over 1 hour'}, ylabel='Neighborhood'>

# %%
# Now we want to know the same, but for the neighborhoods that have the lowest percentages of workers ta commute to work over 1 hour

# %%
LA_Commute_low=LA_Commute.sort_values(by='Commute Time Above 1 Hour',ascending = True)

# %%
LA_Commute_low.head(5).plot.barh(x='Neighborhood',
                            y='Commute Time Above 1 Hour', 
                            title='Top 10 neighborhoods with the lowest percentage of commute to work over 1 hour',
                            color='purple')
# Out:
# <Axes: title={'center': 'Top 10 neighborhoods with the lowest percentage of commute to work over 1 hour'}, ylabel='Neighborhood'>

# %%
import matplotlib.pyplot as plt

# Determine the global minimum and maximum values for the x-axis
max_value = max(LA_Commute_top['Commute Time Above 1 Hour'].max(), LA_Commute_low['Commute Time Above 1 Hour'].max())
min_value = min(LA_Commute_top['Commute Time Above 1 Hour'].min(), LA_Commute_low['Commute Time Above 1 Hour'].min())

# Set up the matplotlib figure and axes, specifying the figure size and the layout
fig, axs = plt.subplots(1, 2, figsize=(16, 8)) # 1 row, 2 columns

# Plot the first graph on the first subplot
LA_Commute_top.head(5).plot.barh(x='Neighborhood',
                                   y='Commute Time Above 1 Hour', 
                                   title='Top 5 neighborhoods with the highest percentage of commute to work over 1 hour',
                                 ax=axs[0])
# Set the same x-axis limits for the first graph
axs[0].set_xlim([min_value, max_value])

# Plot the second graph on the second subplot
LA_Commute_low.head(5).plot.barh(x='Neighborhood',
                                    y='Commute Time Above 1 Hour', 
                                    title='Top 5 neighborhoods with the lowest percentage of commute to work over 1 hour',
                                  ax=axs[1])
# Set the same x-axis limits for the second graph
axs[1].set_xlim([min_value, max_value])

# Automatically adjust subplot params to give specified padding
plt.tight_layout()

# Show the plot
plt.show()
